# %%
import pandas as pd
import numpy as np
import requests as rq
from bs4 import BeautifulSoup

# %% [markdown]
# Começamos o processo de scrapping com uma pessoa aleatória (escolhida manualmente, a partir da sessão de comentários e com grande número de amigos) e colocamos na fronteira amigos dele que sejam brasileiros e a partir disso, buscamos os amigos deles e assim sucetivamente. A tabela foi criada depois de algumas interações e mesmo com a limitação precisamos retirar alguns repetidos, saindo de um dataset de 130 mil exemplos para um com 87 mil.
# Está salvo seu id, que será usado em outras requisições, seu "nick", o nome real - caso seja fornecido, estado e quando a conta foi criada.

# %%
params1={'key':'F695AF807551C6BDF76E8CAAF31B2D5B','steamid':'76561198044946492','relationship':'friend'}
params2={'key':'F695AF807551C6BDF76E8CAAF31B2D5B','steamids':'76561198044946492'}
maxit=1000
#fila1=[]
#fila2=['76561198044946492']
##ans=[]
#ans2=[]
#loccountry = []
#personaname = []
#locstatecode = []
#timecreated = []
#realname = []

#for it in range(maxit):
#    print('Round')
#    print(it)
#    print(len(fila1))
#    print(len(fila2))
#    print(len(ans))
#    if(len(fila2)==0) or True:
#        while len(fila1)>100:
#            params2['steamids']=','.join(fila1[0:99])
#            fila1=fila1[100:]
#            prfs=rq.get('http://api.steampowered.com/ISteamUser/GetPlayerSummaries/v0002/',params2).json()['response']['players']
#            brk=False
#            for prf in prfs:
#                if(('loccountrycode' in prf.keys())and prf['loccountrycode']=='BR' and prf['steamid'] not in ans and prf['steamid'] not in fila2  and prf['steamid'] not in fila1):
#                    fila2.append(prf['steamid'])
#                    ans2.append(prf['steamid'])
#                    loccountry.append(prf['loccountrycode'])
#                    personaname.append(prf['personaname'])
#                    if 'locstatecode' in prf:
#                        locstatecode.append(prf['locstatecode'])
#                    else:
#                        locstatecode.append(0)
#                    timecreated.append(prf['timecreated'])
#                    if 'realname' in prf:
#                        realname.append(prf['realname'])
#                    else:
#                        realname.append(0)
#    idx=fila2[0]
#    params1['steamid']=idx
#    fila2=fila2[1:]
#    ans.append(idx)
#    flist=rq.get('http://api.steampowered.com/ISteamUser/GetFriendList/v0001',params1).json()
#    for x in flist['friendslist']['friends']:
#        if x['steamid'] not in fila1 and x['steamid'] not in ans:
#            fila1.append(x['steamid'])

# %%
jogadores3 = []

for i in range(len(ans2)):
    jogadores3.append((ans2[i],loccountry[i],personaname[i], timecreated[i], locstatecode[i], realname[i]))

dataJogadores3 = pd.DataFrame(jogadores, columns = ['id', 'country', 'personaname', 'timecreated', 'state', 'realname'])

dataJogadores3
# Out:
#                        id country             personaname  timecreated state  \
# 0       76561198039897871      BR                  Faiorb   1301245207    27
# 1       76561197984599609      BR                   Zambs   1156951740    27
# 2       76561198038552348      BR          Weather Report   1298422519    15
# 3       76561197966005614      BR                  camela   1082680379    21
# 4       76561198012207611      BR             NullPointer   1248550377    27
# 5       76561198043144410      BR        Nando Fire • KøN   1307806920    21
# 6       76561197983812616      BR                    Finn   1153248719    27
# 7       76561198002433773      BR            Zuzu Molotov   1226188215     0
# 8       76561198040268931      BR                    Font   1302049567    26
# 9       76561198012813057      BR        ARE YOU JEALOUS?   1250353227    05
# 10      76561198016722832      BR               orlandiN!   1258840590    23
# ...

# %%
dataJogadores3 = pd.read_csv('dataJogadores')
i = 0;
dataJogadores3.drop(dataJogadores3.columns[i], axis = 1, inplace=True)
dataJogadores3.reset_index(drop=True)
# Out:
#                       id country             personaname  timecreated  state  \
# 0      76561198039897871      BR                  Faiorb   1301245207     27
# 1      76561197984599609      BR                   Zambs   1156951740     27
# 2      76561198038552348      BR          Weather Report   1298422519     15
# 3      76561197966005614      BR                  camela   1082680379     21
# 4      76561198012207611      BR             NullPointer   1248550377     27
# 5      76561198043144410      BR        Nando Fire • KøN   1307806920     21
# 6      76561197983812616      BR                    Finn   1153248719     27
# 7      76561198002433773      BR            Zuzu Molotov   1226188215      0
# 8      76561198040268931      BR                    Font   1302049567     26
# 9      76561198012813057      BR        ARE YOU JEALOUS?   1250353227      5
# 10     76561198016722832      BR               orlandiN!   1258840590     23
# ...

# %%
dataJogadores3.groupby('state').count()
# Out:
#           id  country  personaname  timecreated  realname
# state
# 0      22036    22036        22036        22036     22034
# 1        543      543          543          543       542
# 2        298      298          298          298       298
# 3        131      131          131          131       131
# 4        499      499          499          499       499
# 5       1332     1332         1332         1332      1332
# 6       1038     1038         1038         1038      1038
# 7       2146     2146         2146         2146      2146
# 8       1327     1327         1327         1327      1327
# 11       648      648          648          648       648
# 13       242      242          242          242       242
# 14       754      754          754          754       754
# 15      5955     5955         5955         5955      5955
# 16       603      603          603          603       603
# 17       455      455          455          455       455
# ...

# %% [markdown]
# Correspondência dos estados
# 01: Acre
# 02: Alagoas
# 03: Amapá
# 04: Amazonas
# 05: Bahia
# 06: Ceara
# 07: Distrito Federal
# 08: Espírito Santo
# 11: Mato Grosso do Sul
# 13: Maranhão
# 14: Mato Grosso
# 15: Minas Gerais
# 16: Pará
# 17: Paraíba
# 18: Paraná
# 20: Piauí
# 21: Rio de Janeiro
# 22: Rio Grande do Norte
# 23: Rio Grande do Sul
# 24: Rondônia
# 25: Roraima
# 26: Santa Catarina
# 27: São Paulo
# 28: Sergipe
# 29: Goias
# 30: Pernambuco
# 31: Tocantins

# %%
#games = []
#gamesid= []
#playtime_forever = []
#playtime_2weeks = []
#ids_games = []
#jogos_jogador = []
params3={'key':'F695AF807551C6BDF76E8CAAF31B2D5B', 'steamid': '76561198039897871'}
for x in range(len(dataJogadores3)):
    id_pessoa = dataJogadores3.loc[x, 'id']
    if id_pessoa not in ids_games:
        print(id_pessoa)
        params3['steamid'] = id_pessoa
        prfs= rq.get('http://api.steampowered.com/IPlayerService/GetRecentlyPlayedGames/v0001/', params3).json()['response']
        if 'games' in prfs.keys():
            prfs = prfs['games']
            for prf in prfs:
                if 'name' in prf.keys() and 'appid' in prf.keys():
                    print(prf['name'])
                    games.append(prf['name'])
                    gamesid.append(prf['appid'])
                    playtime_forever.append(prf['playtime_forever'])
                    playtime_2weeks.append(prf['playtime_2weeks'])
                    ids_games.append(id_pessoa)
# Out:
# 76561198060518368
# Rising Storm/Red Orchestra 2 Multiplayer
# The Witcher 2: Assassins of Kings Enhanced Edition
# Left 4 Dead 2
# METAL GEAR SOLID V: THE PHANTOM PAIN
# The Elder Scrolls V: Skyrim
# Rising Storm 2: Vietnam
# F1 2011
# Darksiders II
# Dead Island
# 76561198070592492
# 76561198321834259
# Grand Theft Auto: San Andreas
# Counter-Strike: Global Offensive
# 76561197994794500
# 76561198000781124
# Last Day of June
# 76561198095239537
# Counter-Strike: Global Offensive
# 76561198035385052
# 76561198054878400
# Duelyst
# Magic 2014
# 76561198068277413
# Counter-Strike: Global Offensive
# PLAYERUNKNOWN'S BATTLEGROUNDS
# 76561198018611121
# 76561198168990166
# 76561198049083478
# Team Fortress 2
# 76561198093242306
# 76561198315765552
# Counter-Strike: Global Offensive
# 76561198060174161
# 76561198079996498
# 76561198125261264
# 76561197960811099
# Cook, Serve, Delicious! 2!!
# Fallout 4
# Project Highrise
# Overcooked
# Crusader Kings II
# 76561198070394042
# ...

# %%
#for i in range(len(games)):
#    jogos_jogador.append((ids_games[i],games[i],gamesid[i],playtime_forever[i], playtime_2weeks[i]))

#dataGames2 = pd.DataFrame(jogos_jogador, columns=['id', 'game_name', 'game_id', 'playtime_forever', 'playtime_2weeks'])
#dataGames2

# %%
#dataGames = pd.read_csv('dataGames.csv')
#i = 0;
#dataGames.drop(dataGames.columns[i], axis = 1, inplace=True)
#frames = [dataGames, dataGames2]
#dataGames3 = pd.concat(frames,  ignore_index=True).drop_duplicates().reset_index(drop=True)
dataGames = pd.read_csv('dataGames3.csv')
i = 0;
dataGames.drop(dataGames.columns[i], axis = 1, inplace=True)
dataGames.reset_index(drop=True)
# Out:
#                        id                           game_name  game_id  \
# 0       76561198039897871                     Team Fortress 2      440
# 1       76561198039897871                      Heat Signature   268130
# 2       76561198039897871              FTL: Faster Than Light   212680
# 3       76561198039897871           Doki Doki Literature Club   698780
# 4       76561198039897871                            RimWorld   294100
# 5       76561198039897871                       Rise to Ruins   328080
# 6       76561198039897871       Shovel Knight: Treasure Trove   250760
# 7       76561197984599609                 Reigns: Her Majesty   717640
# 8       76561198038552348                      Stardew Valley   413150
# 9       76561197966005614  Age of Mythology: Extended Edition   266840
# 10      76561197966005614                    Ragnarok Clicker   493370
# 11      76561197966005614                             Magicka    42910
# ...

# %%
dataCount = dataGames.groupby(['game_name', 'game_id']).agg({"playtime_2weeks": np.sum, "id": pd.Series.nunique, "playtime_forever": np.sum}).sort_values(['playtime_2weeks'], ascending=[False])
listId = dataCount.index.get_level_values(1).tolist()
dataCount
# Out:
#                                                         id  playtime_2weeks  \
# game_name                                   game_id
# Counter-Strike: Global Offensive            730      31043         31522662
# Dota 2                                      570       8459         11671832
# PLAYERUNKNOWN'S BATTLEGROUNDS               578080   11985         10433411
# Tom Clancy's Rainbow Six Siege              359550    3565          2604836
# Grand Theft Auto V                          271590    3863          1877226
# Battlerite                                  504370    4553          1809882
# Warframe                                    230410    1467          1603595
# Team Fortress 2                             440       2066          1411716
# Rocket League                               252950    3122          1377849
# Paladins                                    444090    2714          1249342
# Yu-Gi-Oh! Duel Links                        601510    1796          1195265
# ...

# %%
import time

#genres = []
#id_genres = []
params4={'appids':'730'}
for x in range(6879, len(listId)):
    idJogo = listId[x]
    print(idJogo)
    params4['appids'] = idJogo
    if idJogo not in id_genres:
        prfs= rq.get('http://store.steampowered.com/api/appdetails?appids=', params4).json()[str(idJogo)]
        if 'data' in prfs:
            prfs = prfs['data']
            if 'genres' in prfs:
                prfs = prfs['genres']
                genres.append(prfs)
                print(prfs)
            else:
                genres.append(0)
        else:
            genres.append(0)
        id_genres.append(idJogo)
        time.sleep(1)
# Out:
# 315880
# 726520
# [{'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}, {'id': '28', 'description': 'Simulation'}]
# 393970
# 471170
# [{'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}, {'id': '28', 'description': 'Simulation'}, {'id': '2', 'description': 'Strategy'}]
# 50510
# [{'id': '1', 'description': 'Action'}]
# 601580
# [{'id': '1', 'description': 'Action'}, {'id': '4', 'description': 'Casual'}, {'id': '2', 'description': 'Strategy'}]
# 509850
# [{'id': '1', 'description': 'Action'}, {'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}]
# 19800
# [{'id': '1', 'description': 'Action'}]
# 72310
# 493280
# [{'id': '1', 'description': 'Action'}, {'id': '23', 'description': 'Indie'}, {'id': '70', 'description': 'Early Access'}]
# 613970
# ...

# %%
columns_genres = []
for x in range(len(id_genres)):
    if genres[x] is not 0:
        for y in range(len(genres[x])):
            if genres[x][y]['description'] not in columns_genres:
                columns_genres.append(genres[x][y]['description'])

# %%
games_total = pd.DataFrame(index=id_genres, columns=columns_genres)
for x in range(len(id_genres)):
    if genres[x] is not 0:
        for y in range(len(genres[x])):
            to = 1/len(genres[x])
            descr = genres[x][y]['description']
            games_total.at[id_genres[x], descr] = to
games_total = games_total.fillna(0)
games_total
# Out:
#           Action  Free to Play  Strategy   Violent  Adventure  \
# 730     1.000000      0.000000  0.000000  0.000000   0.000000
# 570     0.333333      0.333333  0.333333  0.000000   0.000000
# 578080  0.200000      0.000000  0.000000  0.200000   0.200000
# 359550  1.000000      0.000000  0.000000  0.000000   0.000000
# 271590  0.500000      0.000000  0.000000  0.000000   0.500000
# 504370  0.500000      0.500000  0.000000  0.000000   0.000000
# 230410  0.333333      0.333333  0.000000  0.333333   0.000000
# 440     0.500000      0.500000  0.000000  0.000000   0.000000
# 252950  0.250000      0.000000  0.000000  0.000000   0.000000
# 444090  0.333333      0.333333  0.000000  0.000000   0.000000
# 601510  0.000000      0.500000  0.500000  0.000000   0.000000
# 252490  0.125000      0.000000  0.000000  0.125000   0.125000
# 107410  0.333333      0.000000  0.333333  0.000000   0.000000
# 433850  0.250000      0.000000  0.000000  0.000000   0.250000
# ...

# %%
import csv

with open('genres.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(genres)

with open('id_genres.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(id_genres)

# %%
dataJogadores3.to_csv('dataJogadores')

# %%
dataGames3.to_csv('dataGames3.csv')

# %%
games_total.to_csv('games_total.csv')
